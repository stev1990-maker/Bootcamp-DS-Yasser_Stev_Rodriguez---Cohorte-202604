# %% [markdown]
# # Caso aplicado - Parque automotor particular del departamento de Boyacá
# ---
#
# Parque automotor activo de servicio particular matriculado en las sedes de tránsito del Departamento de Boyacá, actualizado a vigencia 2024

# %% [markdown]
# ### Datos obtenidos de Datos Abiertos (datos.gov.co)
# - [Link de acceso a metadatos](https://www.datos.gov.co/Transporte/PARQUE-AUTOMOTOR-ACTIVO-DE-SERVICIO-PARTICULAR-DEP/em3d-hmim/about_data)

# %%
# !pip3 install numpy
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.2)

# %%
import pandas as pd
import numpy as np

# Carga de datos
data = pd.read_csv('parque_automotor.csv')
df = data.copy()
df.head()
# Out:
# /var/folders/tf/g4zh87_57zv3517dtpgrm67r0000gn/T/ipykernel_5057/3971235126.py:5: DtypeWarning: Columns (12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('parque_automotor.csv')
#    N        MOTIVO INGRESO  COD DANE  DANE MUN. PROVINCIA MUNICIPIO  \
# 0  1                   NaN        15      15204    BOYACA   COMBITA
# 1  2     MATRICULA INICIAL        15      15759    BOYACA  SOGAMOSO
# 2  3     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
# 3  4  RADICACIÓN DE CUENTA        15      15238    BOYACA   DUITAMA
# 4  5     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
#
#          CLASE    MARCA                           LINEA MODELO    CARROCERIA  \
# 0  MOTOCICLETA   YAMAHA                        DT 175 E   1977       TURISMO
# 1    CAMIONETA    MAZDA         CX-5 IMP AT 4X2 TOURING   2020         WAGON
# 2    CAMIONETA   TOYOTA  C.A.D.C - HILUX 4X4 DOBLE CABI   2020  DOBLE CABINA
# 3    AUTOMOVIL  RENAULT             SYMBOL AUTEHENTIQUE   2005         SEDAN
# 4  MOTOCICLETA  VICTORY         MOTOCICLETA-SWITCH 150C   2022         SPORT
#
#    PASAJEROS TONELAJE CILINDRAJE    SERVICIO  ESTADO BLINDAJE IMPORTADO
# 0        2.0      0.0        175  PARTICULAR  ACTIVO       NO        NO
# 1        5.0      0.0       2488  PARTICULAR  ACTIVO       NO        NO
# 2        5.0      0.0       2393  PARTICULAR  ACTIVO       NO        NO
# 3        5.0      0.0       1400  PARTICULAR  ACTIVO       NO        NO
# 4        2.0      0.0        149  PARTICULAR  ACTIVO       NO        NO

# %% [markdown]
# ### 1. Cuantos registros y columnas tiene el conjunto de datos?

# %%
df.shape
# Out:
# (182379, 18)

# %% [markdown]
# ### 2. Que tipos de datos tiene el conjunto de datos, y cuantos valores no-nulos tiene?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182379 entries, 0 to 182378
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   N               182379 non-null  int64
#  1   MOTIVO INGRESO  156981 non-null  object
#  2   COD DANE        182379 non-null  int64
#  3   DANE MUN.       182379 non-null  int64
#  4   PROVINCIA       182379 non-null  object
#  5   MUNICIPIO       182379 non-null  object
#  6   CLASE           182368 non-null  object
#  7   MARCA           182366 non-null  object
#  8   LINEA           179141 non-null  object
#  9   MODELO          182331 non-null  object
#  10  CARROCERIA      169376 non-null  object
#  11  PASAJEROS       182228 non-null  float64
#  12  TONELAJE        177751 non-null  object
#  13  CILINDRAJE      182286 non-null  object
#  14  SERVICIO        182366 non-null  object
#  15  ESTADO          182379 non-null  object
#  16  BLINDAJE        182379 non-null  object
#  17  IMPORTADO       182379 non-null  object
# dtypes: float64(1), int64(3), object(14)
# memory usage: 25.0+ MB

# %% [markdown]
# ### 3. La variable tonelaje parace tener datos nulos. Reemplazalos por 0 y convierte la columna en formato float. En caso de error, fuerza la columna a convertir todos sus valores en formato numerico (errors = 'coerce'), y reemplaza los nulos por cero.

# %%
df["TONELAJE"].dtype
# Out:
# dtype('O')

# %%
df['TONELAJE'] = df['TONELAJE'].replace('NA', 0).astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['TONELAJE'] = df['TONELAJE'].replace('NA', 0).astype(float)
#
# File c:\Users\JUANC\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\JUANC\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\JUANC\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\JUANC\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File c:\Users\JUANC\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\JUANC\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\JUANC\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '0EA4F2671887'

# %%
df['TONELAJE'] = pd.to_numeric(df['TONELAJE'], errors='coerce')

# %%
df["TONELAJE"] = df["TONELAJE"].fillna(0)

# %% [markdown]
# ### 4. Con el fin de evitar discrepancias en el futuro, se hace necesario que al igual que la variable TONELAJE, las variables MODELO, CILINDRAJE y PASAJEROS cumplan con la condicion de ser numericas, y además reemplazar sus valores nulos por la media. Realiza una función con el fin de agilizar ese proceso.

# %%
def limpiar_columnas_numericas(df, columnas):
    """
    Funcion para convertir columnas a numéricas y reemplazar valores nulos con la media
    
    Parámetros:
        df: DataFrame de pandas
        columnas: Lista de nombres de columnas a limpiar
    
    Retorna:
        DataFrame con las columnas limpiadas
    """
    for columna in columnas:
        # Convertir a numérico (los no numéricos se convierten en NaN)
        df[columna] = pd.to_numeric(df[columna], errors='coerce')
        
        # Calcular la media y reemplazar NaN
        media = df[columna].mean()
        df[columna].fillna(media, inplace=True)
    
    return df

# %%
df = limpiar_columnas_numericas(df, ["CILINDRAJE", "PASAJEROS", "MODELO"])
df
# Out:
# C:\Users\JUANC\AppData\Local\Temp\ipykernel_192\106583294.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[columna].fillna(media, inplace=True)
#              N        MOTIVO INGRESO  COD DANE  DANE MUN. PROVINCIA MUNICIPIO  \
# 0            1                   NaN        15      15204    BOYACA   COMBITA
# 1            2     MATRICULA INICIAL        15      15759    BOYACA  SOGAMOSO
# 2            3     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
# 3            4  RADICACIÓN DE CUENTA        15      15238    BOYACA   DUITAMA
# 4            5     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
# ...        ...                   ...       ...        ...       ...       ...
# 182374  182375  RADICACIÓN DE CUENTA        15      15516    BOYACA     PAIPA
# 182375  182376  RADICACIÓN DE CUENTA        15      15759    BOYACA  SOGAMOSO
# 182376  182377  RADICACIÓN DE CUENTA        15      15516    BOYACA     PAIPA
# 182377  182378  RADICACIÓN DE CUENTA        15      15238    BOYACA   DUITAMA
# 182378  182379     MATRICULA INICIAL        15      15001    BOYACA     TUNJA
#
#               CLASE       MARCA                           LINEA  MODELO  \
# 0       MOTOCICLETA      YAMAHA                        DT 175 E  1977.0
# 1         CAMIONETA       MAZDA         CX-5 IMP AT 4X2 TOURING  2020.0
# 2         CAMIONETA      TOYOTA  C.A.D.C - HILUX 4X4 DOBLE CABI  2020.0
# 3         AUTOMOVIL     RENAULT             SYMBOL AUTEHENTIQUE  2005.0
# 4       MOTOCICLETA     VICTORY         MOTOCICLETA-SWITCH 150C  2022.0
# ...             ...         ...                             ...     ...
# 182374    AUTOMOVIL     RENAULT          SANDERO AUTHENTIQUE MT  2015.0
# 182375    CAMIONETA  LAND ROVER           RANGE ROVER EVOQUE SE  2015.0
# 182376    CAMIONETA   CHEVROLET                   TRACKER LS AT  2015.0
# 182377    AUTOMOVIL        AUDI              Q3 2.0 TFSI LUXURY  2015.0
# 182378    AUTOMOVIL   CHEVROLET                 LINEA DE PRUEBA  2022.0
#
#           CARROCERIA  PASAJEROS  TONELAJE  CILINDRAJE    SERVICIO  ESTADO  \
# 0            TURISMO        2.0       0.0       175.0  PARTICULAR  ACTIVO
# 1              WAGON        5.0       0.0      2488.0  PARTICULAR  ACTIVO
# 2       DOBLE CABINA        5.0       0.0      2393.0  PARTICULAR  ACTIVO
# 3              SEDAN        5.0       0.0      1400.0  PARTICULAR  ACTIVO
# 4              SPORT        2.0       0.0       149.0  PARTICULAR  ACTIVO
# ...              ...        ...       ...         ...         ...     ...
# 182374    HATCH BACK        5.0       0.0      1598.0  PARTICULAR  ACTIVO
# 182375      CABINADO        5.0       0.0      1999.0  PARTICULAR  ACTIVO
# 182376         WAGON        5.0       0.0      1796.0  PARTICULAR  ACTIVO
# 182377         WAGON        5.0       0.0      1984.0  PARTICULAR  ACTIVO
# 182378           NaN        5.0       0.0        10.0  PARTICULAR  ACTIVO
#
#        BLINDAJE IMPORTADO
# 0            NO        NO
# 1            NO        NO
# 2            NO        NO
# 3            NO        NO
# 4            NO        NO
# ...         ...       ...
# 182374       NO        NO
# 182375       NO        NO
# 182376       NO        NO
# 182377       NO        NO
# 182378       NO        NO
#
# [182379 rows x 18 columns]

# %% [markdown]
# ### 5. Imprime un cuadro con el detalle de estadísticas generales como media, mediana, mínimo, máximo; para las variables cuantitativas del conjunto de datos.

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
df[["MODELO", "PASAJEROS", "CILINDRAJE", "TONELAJE"]].describe()
# Out:
#          MODELO  PASAJEROS  CILINDRAJE   TONELAJE
# count 182379.00  182379.00   182379.00  182379.00
# mean    2004.93       4.08     1928.58      35.94
# std       19.00      20.66   193875.10   10490.54
# min        1.00       0.00        0.00       0.00
# 25%     1995.00       2.00      185.00       0.00
# 50%     2011.00       5.00     1400.00       0.00
# 75%     2018.00       5.00     1800.00       0.00
# max     2025.00    5998.00 79541698.00 4021650.00

# %% [markdown]
# ### 6. Cuales son los 5 municipios con mayor cantidad de vehiculos matriculados?

# %%
df.value_counts('MUNICIPIO')
# Out:
# MUNICIPIO
# COMBITA                  34028
# TUNJA                    30362
# SOGAMOSO                 21944
# DUITAMA                  20172
# NOBSA                    14136
# PAIPA                    13000
# SANTA ROSA DE VITERBO    11766
# CHIQUINQUIRA              7639
# MONIQUIRA                 5072
# PUERTO BOYACA             4881
# VILLA DE LEYVA            4794
# SABOYA                    3991
# GUATEQUE                  3432
# SOATA                     2564
# GARAGOA                   1758
# RAMIRIQUI                 1695
# MIRAFLORES                1140
# AQUITANIA                    4
# BOYACA                       1
# Name: count, dtype: int64

# %%
df["MUNICIPIO"].value_counts().head()
# Out:
# MUNICIPIO
# COMBITA     34028
# TUNJA       30362
# SOGAMOSO    21944
# DUITAMA     20172
# NOBSA       14136
# Name: count, dtype: int64

# %% [markdown]
# ### 7. Agrupa las marcas por el promedio de cilindraje e identifica el top 10

# %%
cilindraje_marca = df.groupby('MARCA')['CILINDRAJE'].mean().sort_values(ascending=False)
cilindraje_marca.head(10)
# Out:
# MARCA
# AUTOCAR        14500.00
# SHACMAN        13000.00
# KENWORTH        8375.00
# MAN             8300.00
# LORAIN          8195.00
# FREIGHTLINER    7321.50
# STERLING        6370.00
# DINA            6362.00
# PH              5000.00
# HINO            4885.60
# Name: CILINDRAJE, dtype: float64

# %% [markdown]
# ### 8. Cual es la marca más común en cada municipio?

# %%
marca_comun_por_municipio = df.groupby('MUNICIPIO')['MARCA'].agg(lambda x: x.mode()[0])
marca_comun_por_municipio
# Out:
# MUNICIPIO
# AQUITANIA                CHEVROLET
# BOYACA                       BAJAJ
# CHIQUINQUIRA                YAMAHA
# COMBITA                    RENAULT
# DUITAMA                  CHEVROLET
# GARAGOA                      BAJAJ
# GUATEQUE                    TOYOTA
# MIRAFLORES                  SUZUKI
# MONIQUIRA                CHEVROLET
# NOBSA                    CHEVROLET
# PAIPA                    CHEVROLET
# PUERTO BOYACA               YAMAHA
# RAMIRIQUI                CHEVROLET
# SABOYA                      TOYOTA
# SANTA ROSA DE VITERBO      RENAULT
# SOATA                       YAMAHA
# SOGAMOSO                   RENAULT
# TUNJA                    CHEVROLET
# VILLA DE LEYVA           CHEVROLET
# Name: MARCA, dtype: object

# %% [markdown]
# ### 9. Crea una columna calculada para conocer la antiguedad de cada vehiculo (pista: usa la libreria datetime).

# %%
from datetime import datetime
df["ANTIGUEDAD"] = datetime.now().year - df["MODELO"]
df.head()
# Out:
#    N        MOTIVO INGRESO  COD DANE  DANE MUN. PROVINCIA MUNICIPIO  \
# 0  1                   NaN        15      15204    BOYACA   COMBITA
# 1  2     MATRICULA INICIAL        15      15759    BOYACA  SOGAMOSO
# 2  3     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
# 3  4  RADICACIÓN DE CUENTA        15      15238    BOYACA   DUITAMA
# 4  5     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
#
#          CLASE    MARCA                           LINEA  MODELO    CARROCERIA  \
# 0  MOTOCICLETA   YAMAHA                        DT 175 E 1977.00       TURISMO
# 1    CAMIONETA    MAZDA         CX-5 IMP AT 4X2 TOURING 2020.00         WAGON
# 2    CAMIONETA   TOYOTA  C.A.D.C - HILUX 4X4 DOBLE CABI 2020.00  DOBLE CABINA
# 3    AUTOMOVIL  RENAULT             SYMBOL AUTEHENTIQUE 2005.00         SEDAN
# 4  MOTOCICLETA  VICTORY         MOTOCICLETA-SWITCH 150C 2022.00         SPORT
#
#    PASAJEROS  TONELAJE  CILINDRAJE    SERVICIO  ESTADO BLINDAJE IMPORTADO  \
# 0       2.00      0.00      175.00  PARTICULAR  ACTIVO       NO        NO
# 1       5.00      0.00     2488.00  PARTICULAR  ACTIVO       NO        NO
# 2       5.00      0.00     2393.00  PARTICULAR  ACTIVO       NO        NO
# 3       5.00      0.00     1400.00  PARTICULAR  ACTIVO       NO        NO
# 4       2.00      0.00      149.00  PARTICULAR  ACTIVO       NO        NO
#
#    ANTIGUEDAD
# 0       48.00
# 1        5.00
# 2        5.00
# 3       20.00
# 4        3.00

# %% [markdown]
# ### 10. Convierte la columna CILINDRAJE a un array de Numpy, y calcula su media, mediana y desviación estándar.

# %%
cilindraje_np = df["CILINDRAJE"].array

print(np.mean(cilindraje_np))
print(np.median(cilindraje_np))
print(np.std(cilindraje_np))
# Out:
# 1928.5816018322953
# 1400.0
# 193874.56515267637

# %%
# Out:
# <NumpyExtensionArray>
# [ 175.0, 2488.0, 2393.0, 1400.0,  149.0, 1998.0, 1500.0, 1598.0, 1998.0,
#   197.0,
#  ...
#  2000.0, 1598.0, 1598.0, 1598.0, 1599.0, 1598.0, 1999.0, 1796.0, 1984.0,
#    10.0]
# Length: 182379, dtype: float64

# %% [markdown]
# ### 11. Calcula los percentiles 30, 60 y 90 del Array anterior, e interpreta los resultados.

# %%
percentile = np.percentile(cilindraje_np, [30, 60, 90])
percentile
# Out:
# array([ 200., 1586., 2500.])

# %% [markdown]
# ### 12. Por medio de una agrupación, obtener para cada MARCA las siguientes agregaciones de la variable CILINDRAJE: media, mediana, desviación estándar y recuento.

# %%
cilindraje = df.groupby('MARCA')["CILINDRAJE"].agg(["mean", "median", "std", "count"]).sort_values("std", ascending=False)
cilindraje.head()
# Out:
#                    mean     median          std  count
# MARCA
# CHEVROLET    3995.81964 1400.00000 431894.87594  33917
# SUZUKI       3091.51285  185.00000 231173.40064   9230
# NISSAN       2841.14233 2400.00000  45482.38385   8692
# MAZDA        2342.43652 1998.00000  45463.92886   8270
# FREIGHTLINER 7321.50000 9535.00000   6482.52601      8

# %% [markdown]
# ### 13. Realiza una tabla dinamica (pivot table) donde se relacionen cuantos vehiculos se tienen por MUNICIPIO y CLASE.

# %%
pivot_tab = pd.pivot_table(df, index = "MUNICIPIO", columns = "CLASE", values = 'N', aggfunc='count', fill_value=0)
pivot_tab
# Out:
# CLASE                  AMBULANCIA  AUTOMOVIL  BUS  BUSETA  CAMION  \
# MUNICIPIO
# AQUITANIA                       0          1    0       0       0
# BOYACA                          0          0    0       0       0
# CHIQUINQUIRA                    0       1098    2       3     103
# COMBITA                         4      10628   41      24    1053
# DUITAMA                         6      11518   10       8     215
# GARAGOA                         0        297    0       1      13
# GUATEQUE                        1        476   15       6     135
# MIRAFLORES                      1        139    0       1      12
# MONIQUIRA                       1       1080    2       3     111
# NOBSA                           1       4761   12      15     312
# PAIPA                           1       5548    6       7      93
# PUERTO BOYACA                   2         59    0       0      19
# RAMIRIQUI                       0        526    3       2      42
# SABOYA                          1        713   21       2     253
# SANTA ROSA DE VITERBO           6       4773    9       5     455
# SOATA                           1        510   31      15      69
# SOGAMOSO                        9      10171    3       7     221
# TUNJA                           6      15969   25      21     315
# VILLA DE LEYVA                  3       1468    2       0      55
#
# CLASE                  CAMION D.TROQUE  CAMIONETA  CAMPERO  CUATRIMOTO  GRUA  \
# MUNICIPIO
# AQUITANIA                            0          2        0           0     0
# BOYACA                               0          0        0           0     0
# CHIQUINQUIRA                         0        533      678           0     0
# COMBITA                              0       6746     3384           0     1
# DUITAMA                              0       4553     1653           1     2
# GARAGOA                              0        253      288           2     0
# GUATEQUE                             0        632     1100           2     0
# MIRAFLORES                           0        170      205           0     0
# MONIQUIRA                            0       1261     1041           0     0
# NOBSA                                0       1839     1380           0     0
# PAIPA                                0       2163      849           5     0
# PUERTO BOYACA                        0        112       52           3     0
# RAMIRIQUI                            0        584      210           0     0
# SABOYA                               0        771     1000           0     0
# SANTA ROSA DE VITERBO                2       2221     1394           0     2
# SOATA                                0        405      316           0     0
# SOGAMOSO                             0       3794     1669           3     4
# TUNJA                                0       6821     3543           0     3
# VILLA DE LEYVA                       0       1600      743           2     0
#
# CLASE                  MAQ. AGRICOLA  MICRO BUS  MINI BUS  MOTO TRACTOR  \
# MUNICIPIO
# AQUITANIA                          0          0         0             0
# BOYACA                             0          0         0             0
# CHIQUINQUIRA                       0          2         0             0
# COMBITA                            0         58         0             1
# DUITAMA                            0         49         0             0
# GARAGOA                            0          3         0             0
# GUATEQUE                           1          3         0             0
# MIRAFLORES                         0          1         0             0
# MONIQUIRA                          0          9         1             0
# NOBSA                              0         17         0             1
# PAIPA                              0         15         0             0
# PUERTO BOYACA                      0          1         0             0
# RAMIRIQUI                          0          4         0             0
# SABOYA                             0          7         0             0
# SANTA ROSA DE VITERBO              0         10         0             0
# SOATA                              0         17         0             0
# SOGAMOSO                           0         32         0             0
# TUNJA                              0         46         0             1
# VILLA DE LEYVA                     0         13         0             0
#
# CLASE                  MOTOCARRO  MOTOCICLETA  MOTOTRICICLO  TRACTO-CAMION  \
# MUNICIPIO
# AQUITANIA                      0            1             0              0
# BOYACA                         0            1             0              0
# CHIQUINQUIRA                 195         4993             0              2
# COMBITA                      268        11179             3             10
# DUITAMA                       31         2047             1              5
# GARAGOA                       21          873             0              0
# GUATEQUE                      21          963             0              2
# MIRAFLORES                    11          595             1              0
# MONIQUIRA                     46         1462             1              1
# NOBSA                          3         5530             1             10
# PAIPA                         33         4227             0              1
# PUERTO BOYACA                151         4474             0              0
# RAMIRIQUI                      3          307             0              1
# SABOYA                        19         1124             1              0
# SANTA ROSA DE VITERBO          3         2672             0              3
# SOATA                         79         1103             0              0
# SOGAMOSO                      70         5811             2              6
# TUNJA                         23         3396             4              4
# VILLA DE LEYVA                48          826             8              0
#
# CLASE                  VAN  VOLQUETA
# MUNICIPIO
# AQUITANIA                0         0
# BOYACA                   0         0
# CHIQUINQUIRA             0        30
# COMBITA                  0       628
# DUITAMA                  1        72
# GARAGOA                  0         7
# GUATEQUE                 0        75
# MIRAFLORES               0         4
# MONIQUIRA                2        51
# NOBSA                    0       254
# PAIPA                    0        52
# PUERTO BOYACA            0         8
# RAMIRIQUI                1        12
# SABOYA                   0        79
# SANTA ROSA DE VITERBO    0       211
# SOATA                    0        18
# SOGAMOSO                 1       141
# TUNJA                    0       174
# VILLA DE LEYVA           0        26

# %% [markdown]
# ### 14. Realiza un análisis de las primeras 5 marcas únicas del DataFrame, mostrando la cantidad de vehículos, el año promedio y el cilindraje promedio de cada una a través de un bucle for.

# %% [markdown]
# ### 15. Clasifica los vehículos según su antigüedad en "Nuevo" si es menor a 5 años, "Semi-nuevo" si es menor a 10 años o "Viejo" si es mayor a 10 años, todo esto usando la función de pandas ```apply``` con una función personalizada y muestra el conteo de cada categoría.

# %% [markdown]
# **¿Qué es ```apply()``` en Pandas?**
#
# ```apply()``` es un método de Pandas que permite aplicar una función a lo largo de filas o columnas de un DataFrame.
#
# - axis=0 → Aplica la función a cada columna (operación por columnas).
#
# - axis=1 → Aplica la función a cada fila (operación por filas).

# %% [markdown]
# ```python
# import pandas as pd
#
# df = pd.DataFrame({'Nombre': ['Ana', 'Luis', 'Carlos'], 'Edad': [25, 30, 22]})
#
# # Función que clasifica según la edad
# def clasificar_edad(row):
#     return 'Joven' if row['Edad'] < 30 else 'Adulto'
#
# df['Categoria'] = df.apply(clasificar_edad, axis=1)
#
# ################### Resultado #################
#
#    Nombre  Edad Categoria
# 0    Ana    25    Joven
# 1   Luis    30   Adulto
# 2 Carlos    22    Joven

# %%
def clasificar_antiguedad(row):
    if row['ANTIGUEDAD'] < 5:
        return 'Nuevo'
    elif row['ANTIGUEDAD'] < 10:
        return 'Semi-nuevo'
    
    else:
        return 'Viejo'

df['CLASIFICACION_ANTIGUEDAD'] = df.apply(clasificar_antiguedad, axis=1)

print("\nClasificación por antigüedad:")
print(df['CLASIFICACION_ANTIGUEDAD'].value_counts())
# Out:
# Clasificación por antigüedad:
# CLASIFICACION_ANTIGUEDAD
# Viejo         124136
# Semi-nuevo     29212
# Nuevo          29031
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    N        MOTIVO INGRESO  COD DANE  DANE MUN. PROVINCIA MUNICIPIO  \
# 0  1                   NaN        15      15204    BOYACA   COMBITA
# 1  2     MATRICULA INICIAL        15      15759    BOYACA  SOGAMOSO
# 2  3     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
# 3  4  RADICACIÓN DE CUENTA        15      15238    BOYACA   DUITAMA
# 4  5     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
#
#          CLASE    MARCA                           LINEA     MODELO  \
# 0  MOTOCICLETA   YAMAHA                        DT 175 E 1977.00000
# 1    CAMIONETA    MAZDA         CX-5 IMP AT 4X2 TOURING 2020.00000
# 2    CAMIONETA   TOYOTA  C.A.D.C - HILUX 4X4 DOBLE CABI 2020.00000
# 3    AUTOMOVIL  RENAULT             SYMBOL AUTEHENTIQUE 2005.00000
# 4  MOTOCICLETA  VICTORY         MOTOCICLETA-SWITCH 150C 2022.00000
#
#      CARROCERIA  PASAJEROS  TONELAJE  CILINDRAJE    SERVICIO  ESTADO BLINDAJE  \
# 0       TURISMO    2.00000   0.00000   175.00000  PARTICULAR  ACTIVO       NO
# 1         WAGON    5.00000   0.00000  2488.00000  PARTICULAR  ACTIVO       NO
# 2  DOBLE CABINA    5.00000   0.00000  2393.00000  PARTICULAR  ACTIVO       NO
# 3         SEDAN    5.00000   0.00000  1400.00000  PARTICULAR  ACTIVO       NO
# 4         SPORT    2.00000   0.00000   149.00000  PARTICULAR  ACTIVO       NO
#
#   IMPORTADO  ANTIGUEDAD CLASIFICACION_ANTIGUEDAD
# 0        NO    48.00000                    Viejo
# 1        NO     5.00000               Semi-nuevo
# 2        NO     5.00000               Semi-nuevo
# 3        NO    20.00000                    Viejo
# 4        NO     3.00000                    Nuevo

# %% [markdown]
# **¿Qué es lambda en Python?**
# lambda es una forma de definir funciones anónimas, es decir, funciones sin nombre que puedes usar rápidamente dentro de una sola línea de código.

# %% [markdown]
# ```python
# def cuadrado(x):
#     return x ** 2
#
# print(cuadrado(4))  # Salida: 16
#
# # Usando lambda:
#
# cuadrado = lambda x: x ** 2
# print(cuadrado(4))  # Salida: 16
#
# # Otro ejemplo
# multiplicar = lambda a, b: a * b
# print(multiplicar(3, 5))  # Salida: 15
#
# # Otro más:
# df = pd.DataFrame({'Edad': [15, 22, 35, 40]})
#
# df['Categoria'] = df['Edad'].apply(lambda x: "Joven" if x < 30 else "Adulto")
# print(df)

# %%
def clasificar_valor(row, columna):
    if row[columna] < 5:
        return 'Nuevo'
    elif row[columna] < 10:
        return 'Semi-nuevo'
    else:
        return 'Viejo'

df['CLASIFICACION_ANTIGÜEDAD'] = df.apply(lambda row: clasificar_valor(row, 'ANTIGÜEDAD'), axis=1)
print("\nClasificación por antigüedad:")
print(df['CLASIFICACION_ANTIGÜEDAD'].value_counts())
# Out:
# Clasificación por antigüedad:
# CLASIFICACION_ANTIGÜEDAD
# Viejo         124136
# Semi-nuevo     29212
# Nuevo          29031
# Name: count, dtype: int64

# %%
df["CLASIFICACION_ANTIGUEDAD_2"] = df["ANTIGUEDAD"].apply(lambda x: "NUEVO" if x < 5 else "Semi-nuevo")
df
# Out:
#              N        MOTIVO INGRESO  COD DANE  DANE MUN. PROVINCIA MUNICIPIO  \
# 0            1                   NaN        15      15204    BOYACA   COMBITA
# 1            2     MATRICULA INICIAL        15      15759    BOYACA  SOGAMOSO
# 2            3     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
# 3            4  RADICACIÓN DE CUENTA        15      15238    BOYACA   DUITAMA
# 4            5     MATRICULA INICIAL        15      15204    BOYACA   COMBITA
# ...        ...                   ...       ...        ...       ...       ...
# 182374  182375  RADICACIÓN DE CUENTA        15      15516    BOYACA     PAIPA
# 182375  182376  RADICACIÓN DE CUENTA        15      15759    BOYACA  SOGAMOSO
# 182376  182377  RADICACIÓN DE CUENTA        15      15516    BOYACA     PAIPA
# 182377  182378  RADICACIÓN DE CUENTA        15      15238    BOYACA   DUITAMA
# 182378  182379     MATRICULA INICIAL        15      15001    BOYACA     TUNJA
#
#               CLASE       MARCA                           LINEA     MODELO  \
# 0       MOTOCICLETA      YAMAHA                        DT 175 E 1977.00000
# 1         CAMIONETA       MAZDA         CX-5 IMP AT 4X2 TOURING 2020.00000
# 2         CAMIONETA      TOYOTA  C.A.D.C - HILUX 4X4 DOBLE CABI 2020.00000
# 3         AUTOMOVIL     RENAULT             SYMBOL AUTEHENTIQUE 2005.00000
# 4       MOTOCICLETA     VICTORY         MOTOCICLETA-SWITCH 150C 2022.00000
# ...             ...         ...                             ...        ...
# 182374    AUTOMOVIL     RENAULT          SANDERO AUTHENTIQUE MT 2015.00000
# 182375    CAMIONETA  LAND ROVER           RANGE ROVER EVOQUE SE 2015.00000
# 182376    CAMIONETA   CHEVROLET                   TRACKER LS AT 2015.00000
# 182377    AUTOMOVIL        AUDI              Q3 2.0 TFSI LUXURY 2015.00000
# 182378    AUTOMOVIL   CHEVROLET                 LINEA DE PRUEBA 2022.00000
#
#         ... PASAJEROS  TONELAJE  CILINDRAJE    SERVICIO  ESTADO BLINDAJE  \
# 0       ...   2.00000   0.00000   175.00000  PARTICULAR  ACTIVO       NO
# 1       ...   5.00000   0.00000  2488.00000  PARTICULAR  ACTIVO       NO
# 2       ...   5.00000   0.00000  2393.00000  PARTICULAR  ACTIVO       NO
# 3       ...   5.00000   0.00000  1400.00000  PARTICULAR  ACTIVO       NO
# 4       ...   2.00000   0.00000   149.00000  PARTICULAR  ACTIVO       NO
# ...     ...       ...       ...         ...         ...     ...      ...
# 182374  ...   5.00000   0.00000  1598.00000  PARTICULAR  ACTIVO       NO
# 182375  ...   5.00000   0.00000  1999.00000  PARTICULAR  ACTIVO       NO
# 182376  ...   5.00000   0.00000  1796.00000  PARTICULAR  ACTIVO       NO
# 182377  ...   5.00000   0.00000  1984.00000  PARTICULAR  ACTIVO       NO
# 182378  ...   5.00000   0.00000    10.00000  PARTICULAR  ACTIVO       NO
#
#        IMPORTADO ANTIGUEDAD  CLASIFICACION_ANTIGUEDAD  \
# 0             NO   48.00000                     Viejo
# 1             NO    5.00000                Semi-nuevo
# 2             NO    5.00000                Semi-nuevo
# 3             NO   20.00000                     Viejo
# 4             NO    3.00000                     Nuevo
# ...          ...        ...                       ...
# 182374        NO   10.00000                     Viejo
# 182375        NO   10.00000                     Viejo
# 182376        NO   10.00000                     Viejo
# 182377        NO   10.00000                     Viejo
# 182378        NO    3.00000                     Nuevo
#
#        CLASIFICACION_ANTIGUEDAD_2
# 0                      Semi-nuevo
# 1                      Semi-nuevo
# 2                      Semi-nuevo
# 3                      Semi-nuevo
# 4                           NUEVO
# ...                           ...
# 182374                 Semi-nuevo
# 182375                 Semi-nuevo
# 182376                 Semi-nuevo
# 182377                 Semi-nuevo
# 182378                      NUEVO
#
# [182379 rows x 21 columns]

# %% [markdown]
# ### 16. Modifica la columna CILINDRAJE reduciéndola en un 20% solo para los vehículos de la clase "MOTOCICLETA". Compara el tiempo de ejecución entre el uso de ```apply()``` con ```lambda``` y el método vectorizado con ```np.where()```, utilizando %timeit.``

# %% [markdown]
# **```np.where()``` es una función de NumPy que actúa como un "si condicional" vectorizado. Sirve para seleccionar valores basados en una condición, de manera mucho más rápida que ```apply()```.**
#
# **Estructura:**
#
# ```python
# np.where(condición, valor_si_True, valor_si_False)
#
# # Ejemplo:
# edades = np.array([15, 22, 30, 18, 25])
# mayores_de_18 = np.where(edades >= 18, "Adulto", "Menor")
#
# print(mayores_de_18)

# %%
# Método con apply (más lento)
# %timeit df.apply(lambda row: row['CILINDRAJE'] * 0.8 if row['CLASE'] == 'MOTOCICLETA' else row['CILINDRAJE'], axis=1)

# Método vectorizado (más rápido)
# %timeit np.where(df['CLASE'] == 'MOTOCICLETA', df['CILINDRAJE'] * 0.8, df['CILINDRAJE'])
# Out:
# 874 ms ± 6.42 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 9.92 ms ± 146 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
